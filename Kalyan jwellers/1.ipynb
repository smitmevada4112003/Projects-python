# %%
"""
Mini Project.

KALYAN JWELLERS : 

M 
>  65
purchase > 2lk - 3lk    20% 
purchase > 3lk - 5lk 	30% 
purchase > 5lk  	35% 


<65
purchase > 2lk - 3lk    10% 
purchase > 3lk - 5lk 	20% 
purchase > 5lk  	25% 



F
>  65
purchase > 2lk - 3lk    25% 
purchase > 3lk - 5lk 	35% 
purchase > 5lk  	40% 


<65
purchase > 2lk - 3lk    15% 
purchase > 3lk - 5lk 	25% 
purchase > 5lk  	30% 


------------------------------------------------------------
Enter your name : 
Enter gender : 
Enter age : 

Enter product : Ring 
Enter product gram : 20  
current gold price (1 grm) : 5752

-------------------------------------
TOTAL GOLD RATE :  XXXXX 


Making charges (1 gram)  : 845
Total Making CHarges :    TOTAL GOLD  X  MAKING CHARGES 

---------------------------------------
TOTAL AMOUNT : GOLD PRICE + TOTAL MAKING CHARG



DISCOUNT :   25 (AUTOMATIC) 
DIS- AMOUNT : except (making charges) 
-----------------------------------------
total net amount : 

--------------------------------------------
HINT : variables , input , conditional statements 


"""

Name = input("Enter the name : ").upper()
gender = input("Enter the gender : ")
age = int(input("Enter the age : "))
product = input("Enter the Product : ")
grams = float(input("Enter Product grams : "))
gold_price = float(input("Enter the Current gold Price (Per grams) : "))

gold_price = 5752                              
Total_gold_Price = grams * gold_price                # 845 * 5752
print("------------------------------")
print(f"TOTAL_GOLD_PRICE :- {Total_gold_Price}")

Making_charg_per_gram = 845
Total_making_charge = grams * Making_charg_per_gram
print(f"TOTAL_MAKING_CHARGE :- {Total_making_charge}")

Total_Amount = gold_price + Total_making_charge
print("\n----------------------------------------")
print(f"TOTAL_AMOUNT : {Total_Amount}")


Discount = 0

if gender == "M":
    if age>65:
        if 21000< Total_gold_Price <=31000:
            Dicount = 20
        elif 31000< Total_gold_Price <=51000:
            Dicount = 30
        elif Total_gold_Price>51000:
            Dicount = 35
    else:
        if 21000< Total_gold_Price <=31000:
            Dicount = 10
        elif 31000< Total_gold_Price<=51000:
            Dicount = 20
        elif Total_gold_Price>=51000:
            Dicount = 25
elif gender == "F":
    if age>65:
        if 21000< Total_gold_Price <=31000:
            Discount = 25
        elif 31000< Total_gold_Price <=51000:
            Discount = 35
        elif Total_gold_Price>=51000:
            Discount = 40
    else:
        if 21000< Total_gold_Price <=31000:
            Discount = 15
        elif 31000< Total_gold_Price <=51000:
            Discount = 25
        elif Total_gold_Price>=51000:
            Discount = 30

Total_Discount = (Total_gold_Price * Discount) / 100
print(f"TOTAL DISCOUNT : {Total_Discount}")

print("ACCOUNT TYPE : ")

print("NAME :- ",Name)
print("GENDER :- ",gender)
print("Age :- ",age)
print("PRODUCT :- ",product)
print("GRAMS :- ",grams)
print("GOLD_PRICE :- ",gold_price)
print("DISCOUNT :- ",Discount)
print("TOTAL_DISCOUT :- ",Total_Discount)
print("TOTAL_AMOUNT :- ",Total_Amount)
